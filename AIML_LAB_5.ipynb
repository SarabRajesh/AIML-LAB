# %% [markdown]
# <a href="https://colab.research.google.com/github/SarabRajesh/AIML-LAB/blob/main/AIML_LAB_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Assignment 4 Question 1
# Load the dataset
url = "https://raw.githubusercontent.com/selva86/datasets/master/BostonHousing.csv"
df = pd.read_csv(url)
# Display the first few rows of the dataset
df.head()
# Check data types of each feature
df.dtypes
# Out:
# crim       float64
# zn         float64
# indus      float64
# chas         int64
# nox        float64
# rm         float64
# age        float64
# dis        float64
# rad          int64
# tax          int64
# ptratio    float64
# b          float64
# lstat      float64
# medv       float64
# dtype: object

# %%
# Generate a statistical summary of the dataset
summary = df.describe(percentiles=[.25, .50, .75, .90])
summary
# List the names of columns/features
column_names = df.columns.tolist()
column_names
# Out:
# ['crim',
#  'zn',
#  'indus',
#  'chas',
#  'nox',
#  'rm',
#  'age',
#  'dis',
#  'rad',
#  'tax',
#  'ptratio',
#  'b',
#  'lstat',
#  'medv']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Generate a pairplot
sns.pairplot(df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-d609fe29200b> in <cell line: 4>()
#       2 import matplotlib.pyplot as plt
#       3 # Generate a pairplot
# ----> 4 sns.pairplot(df)
#       5 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2177         grid.add_legend()
#    2178
# -> 2179     grid.tight_layout()
#    2180
#    2181     return grid
#
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py in tight_layout(self, *args, **kwargs)
#     121         if self._tight_layout_pad is not None:
#     122             kwargs.setdefault("pad", self._tight_layout_pad)
# --> 123         self._figure.tight_layout(*args, **kwargs)
#     124         return self
# ...

# %%
# Generate a correlation matrix
corr_matrix = df.corr()

# %%
# Generate a heatmap for the correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.show()

# %%
# Define the dependent variable (Price) and independent variables (all numerical features except Price)
dependent_var = 'medv'  # Assuming 'medv' represents the price
independent_vars = df.drop(columns=[dependent_var]).columns.tolist()
# Display the list of dependent and independent variables
print(f"Dependent Variable: {dependent_var}")
print(f"Independent Variables: {independent_vars}")
# Out:
# Dependent Variable: medv
# Independent Variables: ['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat']
